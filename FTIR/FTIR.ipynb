# %%
import numpy as np
import matplotlib.pyplot as plt
w1 = np.loadtxt('próbka5 bioreaktor s.txt',skiprows=4)
print(w1)
# Out:
# [[ 400.000886   77.643459]
#  [ 400.715173   77.581581]
#  [ 401.42946    77.422242]
#  ...
#  [3998.580283   97.074472]
#  [3999.29457    97.074348]
#  [4000.008857   97.077376]]

# %%
# liczyby falowe - X
w1[:,0]
# Out:
# array([ 400.000886,  400.715173,  401.42946 , ..., 3998.580283,
#        3999.29457 , 4000.008857])

# %%
# transmitancje - Y
w1[:,1]
# Out:
# array([77.643459, 77.581581, 77.422242, ..., 97.074472, 97.074348,
#        97.077376])

# %%
plt.plot(w1[:,0], w1[:,1])
plt.xlim(4000,400)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
# ZOOM
plt.plot(w1[:,0], w1[:,1])
plt.xlim(4000,2000)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
# przesuwanie widma "góra-dół"
plt.plot(w1[:,0], w1[:,1]-30)
plt.xlim(4000,400)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)
