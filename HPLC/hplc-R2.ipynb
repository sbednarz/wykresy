# %%
import numpy as np
import matplotlib.pyplot as plt
R2_0 = np.loadtxt('R2/Det2/003_R2_12_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_1 = np.loadtxt('R2/Det2/006_R2_13_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_2 = np.loadtxt('R2/Det2/227_R2_14_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_4 = np.loadtxt('R2/Det2/230_R2_16_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_7 = np.loadtxt('R2/Det2/233_R2_19_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_35 = np.loadtxt('R2/Det2/374_R2_18_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_42 = np.loadtxt('R2/Det2/516_R2_25_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_55 = np.loadtxt('R2/Det2/569_R2_8_04_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

                                  
plt.plot(R2_0[:,0], R2_0[:,1], label='R2 - 0 dni hodowli')
plt.plot(R2_1[:,0], R2_1[:,1], label='R2 - 1 dni hodowli')
plt.plot(R2_2[:,0], R2_2[:,1], label='R2 - 2 dni hodowli')
plt.plot(R2_4[:,0], R2_4[:,1], label='R2 - 4 dni hodowli')
plt.plot(R2_7[:,0], R2_7[:,1], label='R2 - 7 dni hodowli')
plt.plot(R2_35[:,0], R2_35[:,1], label='R2 - 35 dni hodowli')
plt.plot(R2_42[:,0], R2_42[:,1], label='R2 - 42 dni hodowli')
plt.plot(R2_55[:,0], R2_55[:,1], label='R2 - 55 dni hodowli')


plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
# https://www.infor.pl/kalkulatory/ilosci_dni.html?fobosId=FOB0000000000000702537

R2_0 = np.loadtxt('R2/Det2/003_R2_12_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_1 = np.loadtxt('R2/Det2/006_R2_13_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_2 = np.loadtxt('R2/Det2/227_R2_14_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_4 = np.loadtxt('R2/Det2/230_R2_16_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_7 = np.loadtxt('R2/Det2/233_R2_19_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_35 = np.loadtxt('R2/Det2/374_R2_18_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_42 = np.loadtxt('R2/Det2/516_R2_25_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_55 = np.loadtxt('R2/Det2/569_R2_8_04_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

TPA01 = np.loadtxt('TPA/331_Kwas_Tereftalowy_0p1mg_ml - MWD 2.1L- Channel 1.txt', delimiter='\t', skiprows=18)
p021 = np.loadtxt('pozywka-TPA/Det2/232_TPA_021mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

plt.xlim(5,20)


plt.plot(R2_0[:,0], R2_0[:,1], label='R2 - 0 dni')
plt.plot(R2_1[:,0], R2_1[:,1], label='R2 - 1 dni')
plt.plot(R2_2[:,0], R2_2[:,1], label='R2 - 2 dni')
plt.plot(R2_4[:,0], R2_4[:,1], label='R2 - 4 dni')
plt.plot(R2_7[:,0], R2_7[:,1], label='R2 - 7 dni')
plt.plot(R2_35[:,0], R2_35[:,1], label='R2 - 35 dni')
plt.plot(R2_42[:,0], R2_42[:,1], label='R2 - 42 dni')
plt.plot(R2_55[:,0], R2_55[:,1], label='R2 - 55 dni')

plt.plot(TPA01[:,0], TPA01[:,1], label='TPA 0.1mg woda')
plt.plot(p021[:,0], p021[:,1], label='TPA 0.21mg + pożywka')


plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

# %%
import numpy as np
import matplotlib.pyplot as plt
# https://www.infor.pl/kalkulatory/ilosci_dni.html?fobosId=FOB0000000000000702537

R2_0 = np.loadtxt('R2/Det2/003_R2_12_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_1 = np.loadtxt('R2/Det2/006_R2_13_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_2 = np.loadtxt('R2/Det2/227_R2_14_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_4 = np.loadtxt('R2/Det2/230_R2_16_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_7 = np.loadtxt('R2/Det2/233_R2_19_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_35 = np.loadtxt('R2/Det2/374_R2_18_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_42 = np.loadtxt('R2/Det2/516_R2_25_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_55 = np.loadtxt('R2/Det2/569_R2_8_04_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

TPA01 = np.loadtxt('TPA/331_Kwas_Tereftalowy_0p1mg_ml - MWD 2.1L- Channel 1.txt', delimiter='\t', skiprows=18)
p021 = np.loadtxt('pozywka-TPA/Det2/232_TPA_021mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

plt.xlim(5,9)


plt.plot(R2_0[:,0], R2_0[:,1], label='R2 - 0 dni')
plt.plot(R2_1[:,0], R2_1[:,1], label='R2 - 1 dni')
plt.plot(R2_2[:,0], R2_2[:,1], label='R2 - 2 dni')
plt.plot(R2_4[:,0], R2_4[:,1], label='R2 - 4 dni')
plt.plot(R2_7[:,0], R2_7[:,1], label='R2 - 7 dni')
plt.plot(R2_35[:,0], R2_35[:,1], label='R2 - 35 dni')
plt.plot(R2_42[:,0], R2_42[:,1], label='R2 - 42 dni')
plt.plot(R2_55[:,0], R2_55[:,1], label='R2 - 55 dni')

plt.plot(TPA01[:,0], TPA01[:,1], label='TPA 0.1mg woda')
plt.plot(p021[:,0], p021[:,1], label='TPA 0.21mg + pożywka')


plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

# %%
import numpy as np
import matplotlib.pyplot as plt
# https://www.infor.pl/kalkulatory/ilosci_dni.html?fobosId=FOB0000000000000702537

def loa (filename):
    return np.loadtxt(filename, delimiter='\t', skiprows=18)
    

def plo (dataset, label=""):
    plt.plot(dataset[:,0], dataset[:,1], label=label)  


R2_0 = loa('R2/Det2/003_R2_12_02_Spirulina231 - MWD 2.1L- Channel 2.txt')
R2_1 = loa('R2/Det2/006_R2_13_02_Spirulina231 - MWD 2.1L- Channel 2.txt')
R2_2 = loa('R2/Det2/227_R2_14_02_Spirulina231 - MWD 2.1L- Channel 2.txt')
R2_4 = loa('R2/Det2/230_R2_16_02_Spirulina231 - MWD 2.1L- Channel 2.txt')
R2_7 = loa('R2/Det2/233_R2_19_02_Spirulina231 - MWD 2.1L- Channel 2.txt')
R2_35 = loa('R2/Det2/374_R2_18_03_Spirulina231 - MWD 2.1L- Channel 2.txt')
R2_42 = loa('R2/Det2/516_R2_25_03_Spirulina231 - MWD 2.1L- Channel 2.txt')
R2_55 = loa('R2/Det2/569_R2_8_04_Spirulina231 - MWD 2.1L- Channel 2.txt')

TPA01 = loa('TPA/331_Kwas_Tereftalowy_0p1mg_ml - MWD 2.1L- Channel 1.txt')
p021 = loa('pozywka-TPA/Det2/232_TPA_021mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt')

plt.xlim(5,9)


# użycie funkcji 'plo' mniej kodu:
plo(R2_0, 'R2 - 0 dni')
plo(R2_1, 'R2 - 1 dni')
plo(R2_2, 'R2 - 2 dni')
plo(R2_4, 'R2 - 4 dni')
plo(R2_7, 'R2 - 7 dni')
plo(R2_35, 'R2 - 35 dni')
plo(R2_42, 'R2 - 42 dni')
plo(R2_55, 'R2 - 55 dni')
plo(TPA01, 'TPA 0.1mg woda')
plo(p021, 'TPA 0.21mg + pożywka')


plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

# %%
# PRZYKŁAD z 24.10.2024
# "PRZESUWANIE" pików po osi X (czasu retencji)

import numpy as np
import matplotlib.pyplot as plt
# https://www.infor.pl/kalkulatory/ilosci_dni.html?fobosId=FOB0000000000000702537

R2_0 = np.loadtxt('R2/Det2/003_R2_12_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_1 = np.loadtxt('R2/Det2/006_R2_13_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_2 = np.loadtxt('R2/Det2/227_R2_14_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_4 = np.loadtxt('R2/Det2/230_R2_16_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_7 = np.loadtxt('R2/Det2/233_R2_19_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_35 = np.loadtxt('R2/Det2/374_R2_18_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_42 = np.loadtxt('R2/Det2/516_R2_25_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_55 = np.loadtxt('R2/Det2/569_R2_8_04_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

TPA01 = np.loadtxt('TPA/331_Kwas_Tereftalowy_0p1mg_ml - MWD 2.1L- Channel 1.txt', delimiter='\t', skiprows=18)
p021 = np.loadtxt('pozywka-TPA/Det2/232_TPA_021mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

plt.xlim(5,20)


plt.plot(R2_0[:,0], R2_0[:,1], label='R2 - 0 dni')
plt.plot(R2_1[:,0], R2_1[:,1], label='R2 - 1 dni')
plt.plot(R2_2[:,0], R2_2[:,1], label='R2 - 2 dni')
plt.plot(R2_4[:,0], R2_4[:,1], label='R2 - 4 dni')
plt.plot(R2_7[:,0], R2_7[:,1], label='R2 - 7 dni')
plt.plot(R2_35[:,0] + 0.5, R2_35[:,1], label='R2 - 35 dni')  # +0.50 <--------------
plt.plot(R2_42[:,0] + 0.55, R2_42[:,1], label='R2 - 42 dni') # +0.55 <--------------    
plt.plot(R2_55[:,0] + 0.55, R2_55[:,1], label='R2 - 55 dni') # +0.55 <--------------

plt.plot(TPA01[:,0], TPA01[:,1], label='TPA 0.1mg woda')
plt.plot(p021[:,0], p021[:,1], label='TPA 0.21mg + pożywka')


plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

# %%
# PRZYKŁAD z 24.10.2024
# "PRZESUWANIE" pików po osi X (czasu retencji) + ZOOM na interesujący fragment

import numpy as np
import matplotlib.pyplot as plt
# https://www.infor.pl/kalkulatory/ilosci_dni.html?fobosId=FOB0000000000000702537

R2_0 = np.loadtxt('R2/Det2/003_R2_12_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_1 = np.loadtxt('R2/Det2/006_R2_13_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_2 = np.loadtxt('R2/Det2/227_R2_14_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_4 = np.loadtxt('R2/Det2/230_R2_16_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_7 = np.loadtxt('R2/Det2/233_R2_19_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_35 = np.loadtxt('R2/Det2/374_R2_18_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_42 = np.loadtxt('R2/Det2/516_R2_25_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_55 = np.loadtxt('R2/Det2/569_R2_8_04_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

TPA01 = np.loadtxt('TPA/331_Kwas_Tereftalowy_0p1mg_ml - MWD 2.1L- Channel 1.txt', delimiter='\t', skiprows=18)
p021 = np.loadtxt('pozywka-TPA/Det2/232_TPA_021mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

plt.xlim(5,9)


plt.plot(R2_0[:,0], R2_0[:,1], label='R2 - 0 dni')
plt.plot(R2_1[:,0], R2_1[:,1], label='R2 - 1 dni')
plt.plot(R2_2[:,0], R2_2[:,1], label='R2 - 2 dni')
plt.plot(R2_4[:,0], R2_4[:,1], label='R2 - 4 dni')
plt.plot(R2_7[:,0], R2_7[:,1], label='R2 - 7 dni')
plt.plot(R2_35[:,0] + 0.5, R2_35[:,1], label='R2 - 35 dni')  # +0.50 <--------------
plt.plot(R2_42[:,0] + 0.55, R2_42[:,1], label='R2 - 42 dni') # +0.55 <--------------    
plt.plot(R2_55[:,0] + 0.55, R2_55[:,1], label='R2 - 55 dni') # +0.55 <--------------

plt.plot(TPA01[:,0], TPA01[:,1], label='TPA 0.1mg woda')
#plt.plot(p021[:,0], p021[:,1], label='TPA 0.21mg + pożywka')


plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

# %%
# PRZYKŁAD z 24.10.2024
# "PRZESUWANIE" pików po osi X (czasu retencji) + ZOOM na interesujący fragment - WERSJA "jeden na drugim"
# Na tym wykresie dobrze widzać, że po 2 dniu kwas zanikł

import numpy as np
import matplotlib.pyplot as plt
# https://www.infor.pl/kalkulatory/ilosci_dni.html?fobosId=FOB0000000000000702537

R2_0 = np.loadtxt('R2/Det2/003_R2_12_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_1 = np.loadtxt('R2/Det2/006_R2_13_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_2 = np.loadtxt('R2/Det2/227_R2_14_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_4 = np.loadtxt('R2/Det2/230_R2_16_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_7 = np.loadtxt('R2/Det2/233_R2_19_02_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_35 = np.loadtxt('R2/Det2/374_R2_18_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_42 = np.loadtxt('R2/Det2/516_R2_25_03_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
R2_55 = np.loadtxt('R2/Det2/569_R2_8_04_Spirulina231 - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

TPA01 = np.loadtxt('TPA/331_Kwas_Tereftalowy_0p1mg_ml - MWD 2.1L- Channel 1.txt', delimiter='\t', skiprows=18)
p021 = np.loadtxt('pozywka-TPA/Det2/232_TPA_021mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)

plt.xlim(5,9)


plt.plot(R2_0[:,0], R2_0[:,1], label='R2 - 0 dni')
plt.plot(R2_1[:,0], R2_1[:,1] + 1000, label='R2 - 1 dni')
plt.plot(R2_2[:,0], R2_2[:,1] + 2000, label='R2 - 2 dni')
plt.plot(R2_4[:,0], R2_4[:,1] + 3000, label='R2 - 4 dni')
plt.plot(R2_7[:,0], R2_7[:,1] + 4000, label='R2 - 7 dni')
plt.plot(R2_35[:,0] + 0.5, R2_35[:,1] + 5000, label='R2 - 35 dni')  # +0.50 <--------------
plt.plot(R2_42[:,0] + 0.55, R2_42[:,1] + 6000, label='R2 - 42 dni') # +0.55 <--------------    
plt.plot(R2_55[:,0] + 0.55, R2_55[:,1] + 7000, label='R2 - 55 dni') # +0.55 <--------------

#plt.plot(TPA01[:,0], TPA01[:,1], label='TPA 0.1mg woda')
plt.plot(p021[:,0], p021[:,1], label='TPA 0.21mg + pożywka')


plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
