# %%
import numpy as np
import matplotlib.pyplot as plt

p0004 = np.loadtxt('pozywka-TPA/Det2/234_TPA_0004mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
p0028 = np.loadtxt('pozywka-TPA/Det2/233_TPA_0028mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
p021 = np.loadtxt('pozywka-TPA/Det2/232_TPA_021mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
p038 = np.loadtxt('pozywka-TPA/Det2/231_TPA_038mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
p0657 = np.loadtxt('pozywka-TPA/Det2/222_Brzeczka_0657mgTPA - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)


plt.plot(p0004[:,0], p0004[:,1], label='pożywka + TPA 0.004mg')
plt.plot(p0028[:,0], p0028[:,1], label='pożywka + TPA 0.028mg')
plt.plot(p021[:,0], p021[:,1], label='pożywka + TPA 0.21mg')
plt.plot(p038[:,0], p038[:,1], label='pożywka + TPA 0.38mg')
plt.plot(p0657[:,0], p0657[:,1], label='pożywka + TPA 0.657mg')

plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

p0004 = np.loadtxt('pozywka-TPA/Det2/234_TPA_0004mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
p0028 = np.loadtxt('pozywka-TPA/Det2/233_TPA_0028mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
p021 = np.loadtxt('pozywka-TPA/Det2/232_TPA_021mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
p038 = np.loadtxt('pozywka-TPA/Det2/231_TPA_038mg_Brzeczka_czysta - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)
p0657 = np.loadtxt('pozywka-TPA/Det2/222_Brzeczka_0657mgTPA - MWD 2.1L- Channel 2.txt', delimiter='\t', skiprows=18)


plt.plot(p0004[:,0], p0004[:,1], label='pożywka + TPA 0.004mg')
plt.plot(p0028[:,0], p0028[:,1], label='pożywka + TPA 0.028mg')
plt.plot(p021[:,0], p021[:,1], label='pożywka + TPA 0.21mg')
plt.plot(p038[:,0], p038[:,1], label='pożywka + TPA 0.38mg')
plt.plot(p0657[:,0], p0657[:,1], label='pożywka + TPA 0.657mg')

plt.xlim(5,12)
plt.xlabel("Czas retencji, min")
plt.ylabel("Sygnał")
plt.legend()
